# %%
from google.cloud import storage
import os
import glob
import tqdm

# %%
 pip install xmltodict -q

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/content/drive/MyDrive/D4G - ceebios/d4g-ceebios-a11dc912ca4a.json'
storage_client = storage.Client()
    
bucket = storage_client.get_bucket('d4g-ceebios-bdd')

# %%
from google.colab import auth
auth.authenticate_user()
# Out:
# ---------------------------------------------------------------------------
# AuthorizationError                        Traceback (most recent call last)
# <ipython-input-4-1f759c1655bd> in <module>()
#       1 from google.colab import auth
# ----> 2 auth.authenticate_user()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/auth.py in authenticate_user(clear_output)
#     255   if _check_adc(_CredentialType.USER):
#     256     return
# --> 257   raise _errors.AuthorizationError('Failed to fetch user credentials')
#     258
#     259
#
# AuthorizationError: Failed to fetch user credentials

# %%
# !gcloud init
# Out:
# Welcome! This command will take you through the configuration of gcloud.
#
# Settings from your current configuration [default] are:
# component_manager:
#   disable_update_check: 'True'
# core:
#   account: barkova.anastasia@gmail.com
#
# Pick configuration to use:
#  [1] Re-initialize this configuration [default] with new settings
#  [2] Create a new configuration
# Please enter your numeric choice:  1
#
# Your current configuration has been set to: [default]
#
# You can skip diagnostics next time by using the following flag:
#   gcloud init --skip-diagnostics
#
# Network diagnostic detects and fixes local network connection issues.
# Reachability Check passed.
# Network diagnostic passed (1/1 checks passed).
#
# Choose the account you would like to use to perform operations for this
# configuration:
#  [1] barkova.anastasia@gmail.com
#  [2] Log in with a new account
# Please enter your numeric choice:  1
#
# You are logged in as: [barkova.anastasia@gmail.com].
#
# Pick cloud project to use:
#  [1] d4g-ceebios
#  [2] youtube-12-11
#  [3] Enter a project ID
#  [4] Create a new project
# Please enter numeric choice or text value (must exactly match list item):  1
#
# Your current project has been set to: [d4g-ceebios].
#
# Do you want to configure a default Compute Region and Zone? (Y/n)?  n
#
# Your Google Cloud SDK is configured and ready to use!
#
# * Commands that require authentication will use barkova.anastasia@gmail.com by default
# * Commands will reference project `d4g-ceebios` by default
# Run `gcloud help config` to learn how to change individual settings
#
# This gcloud configuration is called [default]. You can create additional configurations if you work with multiple accounts and/or projects.
# Run `gcloud topic configurations` to learn more.
#
# Some things to try next:
#
# * Run `gcloud --help` to see the Cloud Platform services you can interact with. And run `gcloud help COMMAND` to get help on any gcloud command.
# * Run `gcloud topic --help` to learn about advanced features of the SDK like arg files and output formatting
# * Run `gcloud cheat-sheet` to see a roster of go-to `gcloud` commands.

# %% [markdown]
# ### Import functions and classes

# %%
import re
import xmltodict
import json
import xml.etree.ElementTree as ET
from pprint import pprint

# This code was written by Lucas Le Corvec
def _unique(sequence):
    """Function to remove duplicates while keeping inserterion order.
    """
    seen = set()
    return [x for x in sequence if not (x in seen or seen.add(x))]

def authors_list(value):
    """Function to return main author and other authors through a list of lists.
    """
    if not value:  # Means list is empty
        return '', []
    main_author = value[0][0] + ' ' + value[0][1]
    if len(value) > 1:
        others = [x[0] + ' ' + x[1] for x in value[1:]]
        return main_author, others
    else:
        return main_author, []


def _has_numbers(string):
    """Function to check if string has numeric character.
    """
    return any(char.isdigit() for char in string)

def _numeric_caracter_splitting(string):
    """Function to split figure reference that have a numeric character inside it.
    """
    if 'fig' in string.lower() and _has_numbers(string):
        return re.findall('\d*\D+', string)
    else:
        return string


def figure_ref_detection(text):
    """Function to find figure references in paragraph.
    """
    # Have to take care of figures ref separated by 'and' or/and by ','
    # Plus1 : sometimes '-' is used to reference several figures
    # Plus2 : have to remove any '(' or ')' ',' in figures names after regex

    # Taking care of splitted figure reference that has figure reference inside. Exemple : fig.4B
    # And then flattening the new list
    text_raw = [_numeric_caracter_splitting(x) for x in text.split(' ')]
    text_splitted = []
    for element_1 in text_raw:
        if type(element_1) == list:
            for element_2 in element_1:
                text_splitted.append(element_2)
        else:
            text_splitted.append(element_1)

    figure_ref = []
    for index, element in enumerate(text_splitted):
        if ('fig' in element.lower()) and (
                8 >= len(element) >= 3):  # All figure references "should" validate this condition ==> To verify
            try:
                element_to_add = text_splitted[index + 1]  # Get next element as it is the figure reference
                figure_ref.append(element_to_add)
            except IndexError:
                continue

            try:
                text_splitted[index + 2]  # Case 0 : when the figure reference is at the end of paragraph
            except IndexError:
                continue

            if element_to_add.endswith(','):  # Case 1 : element ends with ',' meaning an other figure ref follows
                new_counter = index + 2
                while text_splitted[new_counter].endswith(
                        ','):  # Case 1.1 : several figures references separated by ','
                    figure_ref.append(text_splitted[new_counter])
                    new_counter += 1
                    try:
                        text_splitted[
                            new_counter]  # If it fails it means that the next figure reference is at the end of paragraph
                    except:
                        continue
                if new_counter + 1 == len(text_splitted):  # Case 1.2 : last figure reference is at the end of paragraph
                    figure_ref.append(text_splitted[new_counter])
                    continue
                if text_splitted[new_counter + 1].lower() == 'and':
                    figure_ref.append(
                        text_splitted[new_counter])  # Case 1.3 : get last figure reference, separated by 'and'
                    figure_ref.append(text_splitted[new_counter + 2])
                else:
                    figure_ref.append(
                        text_splitted[new_counter])  # Case 1.4 : get last figure reference, separated by ','

            elif text_splitted[index + 2].lower() == 'and':  # Case 2 : only two figures references, separated by 'and'
                figure_ref.append(text_splitted[index + 3])

            else:  # Case 3 : only one figure reference
                continue  # Element already added

    figure_ref_cleaned_re = [re.sub(r'[,()\'´:"”’.;]', '', x) for x in figure_ref]  # Regex to clean figure references

    # Check if all figure references do have a numeric character and are no longer than 2 characters
    # ==> Maybe double check this rule ...
    for index, element in enumerate(figure_ref_cleaned_re):
        if not _has_numbers(
                element):  # Case 3 : when auhtor doesn't write the figure number for next figure reference. Exemple : fig. 3D, E and F
            figure_ref_cleaned_re[index] = figure_ref_cleaned_re[index - 1][0] + element

    figure_ref_cleaned_len = [x for x in figure_ref_cleaned_re if len(x) <= 3]

    return _unique(figure_ref_cleaned_len)  # In order to remove duplicates


def match_figure_ref(doi, figure_list, dict_figure):
    """Function that matches the figures reference from paragraphs to actual figures in
    dict_figures.
    """
    graphic_ref_list = []
    for element_1 in figure_list:
        # Strip anything that is not digit (including blank spaces)
        figure_ref = re.sub(r'[A-Za-z,()\'´:"”’.; +]', '', element_1)

        for element_2 in dict_figure[doi]:
            # Strip anything that is not digit (including blank spaces)
            graph_ref = re.sub(r'[A-Za-z,()\'´:"”’.; +]', '', element_2)
            # Matching figure_ref from paragraph to figure_ref from figures
            if str(figure_ref) == str(graph_ref):
                graphic_ref_list.append(dict_figure[doi][element_2]['graphic_ref'])

    return graphic_ref_list


## Code by Paul-Henri & Anastasia

def arborescence(filename, counter):
    dic = _file_to_dic(filename)
    d = {}
    _dic_to_keys_dic(dic, d, counter)
    pprint(d)


def _dic_to_keys_dic(dic, keys_dic, counter):
    counter += 1
    keys = dic.keys()
    for key in keys:
        if isinstance(dic[key], dict):
            keys_dic[key] = {}
            nested = dic[key]
            nested_keys = nested.keys()
            _dic_to_keys_dic(dic[key], keys_dic[key], counter)
            counter -= 1
        else:
            keys_dic[key] = counter

def _file_to_dic(f):
    with open(f, "rb") as file:
        document = xmltodict.parse(file)
    json_file_text = json.dumps(document)
    json_file = json.loads(json_file_text)
    dic = json_file['article']
    return dic


class Biorxiv_Plos_Parser:
    # This class can parse the following PLOS journals:
    # PLOS One, Genetics, Biology, Computational Biology, Clinical Trials, Neglected Tropical Diseases, Pathogens
    # And it also parses bioRxiv articles

    def __init__(self, xml, journal_type):
        self.xml = xml
        self.journal_type = journal_type

    def get_doi(self):
        # Transform the XML file into a parsable object
        tree = ET.parse(self.xml)
        root = tree.getroot()

        # Get the DOI
        doi = root.find(".//*[@pub-id-type='doi']").text
        return doi

    def get_paragraphs(self):
        # Transform the XML file into a parsable object
        tree = ET.parse(self.xml)
        root = tree.getroot()

        # Get the DOI
        doi = root.find(".//*[@pub-id-type='doi']").text

        # Get the paragraphs and their associated figures
        ## Lists of paragraphs and figures in the body + list of hashes
        figures = []
        hashes = []
        p = []

        ## Select all the paragraphs in the body with xpath (sec)
        e = root.findall(".//sec/p")

        ## Extract the paragraphs and figures
        for i in e:
            paragraph = "".join(i.itertext())
            p.append(paragraph)
            figures.append(figure_ref_detection(paragraph))
            hashes.append(hash(paragraph + doi))

        # Build the paragraph dictionary
        paragraphs = []
        doi = self.get_doi()

        for doc_id, paragraph, figure_list, id_ in zip(hashes, p, figures, hashes):
            if figure_list != []:
                temp_dic = {}
                temp_dic['content'] = paragraph.replace('\t', '').replace('\n', '')
                meta_dic = {}
                meta_dic['document_id'] = doc_id
                meta_dic['figures_ids'] = figure_list
                meta_dic['type'] = 'paragraph'
                meta_dic['doi'] = doi
                temp_dic['meta'] = meta_dic
                paragraphs.append(temp_dic)
            else:
                continue

        return paragraphs

    def get_article(self):
        # Transform the XML file into a parsable object
        tree = ET.parse(self.xml)
        root = tree.getroot()

        # Get the DOI
        doi = root.find(".//*[@pub-id-type='doi']").text

        # Get the Abstract
        abstract = []
        for r in root.findall(".//front/article-meta/abstract"):
            abstract_paragraph = "".join(r.itertext()).replace('\t', '').replace('\n', '')
            abstract.append(abstract_paragraph)

        abstract = ''.join(abstract)

        # Get the Title
        title = root.find(".//article-title").text

        # Get the Authors
        authors = []
        for a in root.findall(".//*[@contrib-type='author']/name/surname"):
            author = "".join(a.itertext())
            authors.append(author)

        # Get the journal
        journal = root.find(".//journal-title").text

        # Build the articles dictionary
        article = {}
        article['id'] = hash(doi + abstract)
        article['content'] = abstract

        meta_article = {}
        meta_article['title'] = title
        meta_article['authors'] = authors
        meta_article['journal'] = journal
        meta_article['doi'] = doi

        article['meta'] = meta_article

        return article

    def get_figures(self):

        # Transform the XML file into a parsable object
        tree = ET.parse(self.xml)
        root = tree.getroot()

        # Get the figures URLs
        figure_urls = []
        for r in root.findall(".//fig/object-id"):
            figure_url = "".join(r.itertext())
            figure_urls.append(figure_url)
            if self.journal_type == 'biorxiv':
                figure_urls = [f for f in figure_urls if 'biorxiv' in f]

        # Get the figures IDs
        ids = []
        for l in root.findall(".//fig/label"):
            label = "".join(l.itertext())
            if self.journal_type == 'plos':
                ids.append(label[-1])
            else:
                ids.append(label[-2])

        # Create a string of figure title + its caption. It sometimes can happen that the title or the caption
        # are not present. It will be filled with "Not available" text.
        captions = []
        for fig in root.findall(".//fig"):
            if fig.findall('caption/p') != []:
                c = fig.findall('caption/p')[0]
                caption = "".join(c.itertext()).replace('\t', '').replace('\n', '')
            else:
                caption = 'Caption not found'

            if fig.findall('caption/title') != []:
                t = fig.findall('caption/title')[0]
                title = "".join(t.itertext()).replace('\t', '').replace('\n', '')
            else:
                title = "Title not found"

            captions.append(title + '; ' + caption)

        # Build the figures dictionary
        figures = []
        for url, caption, id_ in zip(figure_urls, captions, ids):
            dic = {}
            dic['id'] = id_
            dic['content'] = caption

            meta_dic = {}
            meta_dic['url'] = url
            meta_dic['type'] = 'figure'
            meta_dic['fig_id'] = self.get_doi() + f'_{id_}'
            meta_dic['doi'] = self.get_doi()
            dic['meta'] = meta_dic
            figures.append(dic)

        return figures

# %% [markdown]
# ### Test access to the bucket

# %%
bucket
# Out:
# <Bucket: d4g-ceebios-bdd>

# %%
blobs = list(bucket.list_blobs(prefix='raw_data/xml'))

# %%
len(blobs)
# Out:
# 9531

# %%
# !gsutil cp -r gs://d4g-ceebios-bdd/raw_data/items25-00-2022.json temp_file.json
# Out:
# Copying gs://d4g-ceebios-bdd/raw_data/items25-00-2022.json...
# / [1 files][ 30.4 MiB/ 30.4 MiB]
# Operation completed over 1 objects/30.4 MiB.

# %%
# Copy all files to the directory xml from GCS
os.mkdir('xml')

# %%
def load(file_path):
    os.system(f'gsutil -m cp -r {file_path} xml')
    # tree = ET.parse('temp_file.xml')
    # root = tree.getroot()
    # os.system('rm temp_file.xml')
    # return tree, root

file = 'gs://d4g-ceebios-bdd/raw_data/xml'
load(file)
# tree, root

# %%
list_files = [f for f in os.listdir('xml/xml')]
print(len(list_files))
# Out:
# 9530

# %%
file = json.load(open('/content/temp_file.json'))

# %% [markdown]
# ### Parse the xml elements and save them

# %%
path_all = [file for file in glob.glob(os.path.join('/content/xml/xml', '*.xml'))]
journal_type = 'plos'

path_to_db_fig = '/content/xml/parsed_plos_fig'
path_to_db_para = '/content/xml/parsed_plos_para'

# Create directories to save the parsed files if the don't exist
if not os.path.exists(path_to_db_fig):
  os.mkdir(path_to_db_fig)
if not os.path.exists(path_to_db_para):
  os.mkdir(path_to_db_para)

not_parsed_figs = []
not_parsed_paras = []
for file in tqdm.tqdm(path_all):
    PLOS = Biorxiv_Plos_Parser(file, journal_type)
    doi = PLOS.get_doi()
    doi = doi.replace('/', '-')

    #If the xml cannot be parsed it will be added to the list, and the iteration continues
    try:
      figs = PLOS.get_figures()
  
    except:
      print(f'Could not parse figures for {file}')
      not_parsed_figs.append(file)
      continue

    #article_meta = PLOS.get_article()
    try:
      paragraphs = PLOS.get_paragraphs()
    except:
      print(f'Could not parse paragraphs for {file}')
      not_parsed_paras.append(file)
      continue

    # Save dicts as json
    with open(os.path.join(path_to_db_fig, f'{doi}_fig.json'), 'w') as f1:
        json.dump(figs, f1)

    with open(os.path.join(path_to_db_para, f'{doi}_paragraphs.json'), 'w') as f2:
        json.dump(paragraphs, f2)
# Out:
#   7%|▋         | 632/9530 [00:46<09:09, 16.20it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0001439.xml
#  15%|█▍        | 1416/9530 [01:48<09:39, 14.01it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0017828.xml
#  16%|█▌        | 1528/9530 [01:57<06:56, 19.20it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0018039.xml
#  25%|██▌       | 2392/9530 [03:01<08:32, 13.93it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0018318.xml
#  52%|█████▏    | 4963/9530 [06:15<04:31, 16.85it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0018277.xml
#  53%|█████▎    | 5054/9530 [06:22<05:50, 12.77it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0018755.xml
#  61%|██████▏   | 5853/9530 [07:28<03:18, 18.54it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0014799.xml
#  62%|██████▏   | 5897/9530 [07:31<03:58, 15.20it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0017775.xml
#  74%|███████▍  | 7084/9530 [09:16<02:50, 14.37it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0006577.xml
#  79%|███████▊  | 7501/9530 [09:47<02:57, 11.43it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0018859.xml
#  94%|█████████▎| 8920/9530 [11:41<02:44,  3.71it/s]
# Could not parse paragraphs for /content/xml/xml/10.1371-journal.pone.0014631.xml
# 100%|██████████| 9530/9530 [12:30<00:00, 12.69it/s]

# %%
print((len(not_parsed_figs)))
print((len(not_parsed_paras)))
# Out:
# 0
# 11

# %%
if not_parsed_figs:
  json.dump(not_parsed_figs, open('/content/xml/2022-06-11_not_parsed_figs_plos.json', 'w'))
if not_parsed_paras:
  json.dump(not_parsed_paras, open('/content/xml/2022-06-11_not_parsed_paras_plos.json', 'w'))

# %%
# !zip -r /content/parsed_plos_fig.zip /content/xml/parsed_plos_fig
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0221397_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0066370_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0053066_fig.json (stored 0%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0007311_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0098200_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0057192_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0180284_fig.json (deflated 51%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0034023_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0055192_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0213268_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0251790_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0049990_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0042292_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0134355_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1007965_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0092834_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0109007_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0050831_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0008125_fig.json (deflated 52%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.3000394_fig.json (stored 0%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0210557_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.2006285_fig.json (stored 0%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0209273_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0136073_fig.json (deflated 83%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0024748_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0241705_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0095384_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0247124_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0001021_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0066832_fig.json (deflated 43%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0086571_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0222707_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0063601_fig.json (deflated 54%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0004688_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.ppat.1000904_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0142757_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0057039_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0066559_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0088581_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0170683_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0193110_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0233167_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0175671_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0229459_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0054787_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0154144_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0032980_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0117442_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0089913_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0124057_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0074713_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1003763_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0044847_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0218421_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0192153_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0164271_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0005604_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0008487_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0205407_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0148034_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0104933_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0177208_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0268048_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0185586_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0084117_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0026208_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0187461_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0246651_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0157800_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0006300_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0147394_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0143982_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0132103_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0121965_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0010668_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0266100_fig.json (deflated 79%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0145113_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0182749_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0127176_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0198236_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0167074_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0182910_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0250272_fig.json (deflated 79%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0088613_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0138387_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0191886_fig.json (deflated 80%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0245218_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0102920_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1009683_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0160776_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0173505_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0132338_fig.json (deflated 47%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0037583_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.1000501_fig.json (deflated 53%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0002918_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0124625_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0131800_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0012374_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0002157_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0051557_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0165412_fig.json (deflated 81%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0159869_fig.json (deflated 51%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0263576_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0080431_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0042651_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0004335_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0109971_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0001586_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0109907_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0084130_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0091224_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0067486_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0000444_fig.json (deflated 46%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0173694_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0237894_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0232509_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0084529_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0263122_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0209881_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0007005_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0238695_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0137838_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0157674_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1006157_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0178077_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1007369_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0215645_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1003821_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0102430_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0018260_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0070449_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0219797_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0184060_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0048068_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0222047_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0076621_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0064567_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0047368_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0142893_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0001448_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0002442_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0098406_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0248583_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0043492_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0139463_fig.json (deflated 82%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0173007_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.1001641_fig.json (deflated 48%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0008776_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0019762_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0166118_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0173812_fig.json (deflated 38%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0060019_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0117307_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0002825_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0173859_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0034005_fig.json (deflated 37%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0095890_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0172977_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0173156_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0224316_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0178066_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0141167_fig.json (deflated 51%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0169067_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0195255_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.0050194_fig.json (stored 0%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0048406_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0214986_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0143282_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0210122_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0064620_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0059757_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0079902_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0059988_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.0060162_fig.json (deflated 50%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0080872_fig.json (deflated 53%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0107811_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0155719_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.3000736_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0249893_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0010609_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0072729_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0211388_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0230269_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0024863_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0012380_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0151436_fig.json (deflated 50%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0063570_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0007712_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0031314_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1000428_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0241452_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0254097_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0150895_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0151137_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0018460_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.0060122_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0074989_fig.json (deflated 81%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0034472_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0115108_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0137429_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0147004_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.0040277_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0219128_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0148958_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1003739_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.2004261_fig.json (deflated 41%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0075516_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0076688_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0092976_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0105510_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0004195_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0050304_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0159886_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0066906_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0065861_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0001618_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0120168_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0103267_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0068603_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.3000437_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0163121_fig.json (deflated 89%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0124707_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0079712_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0221706_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0029332_fig.json (deflated 39%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0003473_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0095551_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0104385_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0144601_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0192869_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0154057_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0121157_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0192766_fig.json (deflated 79%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0105022_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0210792_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0060704_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0107929_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0210849_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0076430_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0236590_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0007393_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.0050272_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0181188_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0108725_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0105982_fig.json (deflated 43%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0135928_fig.json (deflated 80%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0171974_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0256961_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0263504_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0027785_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0249113_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0129342_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0225633_fig.json (deflated 81%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0170110_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0178568_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0213946_fig.json (deflated 81%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0045552_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0032819_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0181769_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0049965_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0029549_fig.json (deflated 36%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0221667_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0183143_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0203561_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.0040341_fig.json (deflated 40%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0005104_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0097783_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0233389_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0232692_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1003706_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0118403_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0135136_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0010958_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0211340_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0157632_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0049824_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0036479_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0028749_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0138216_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0103783_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0033914_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0140280_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0038460_fig.json (deflated 36%)
#   adding: content/xml/parsed_plos_fig/10.1371-image.pbio.v17.i02_fig.json (stored 0%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0194372_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0162899_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0024128_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0004115_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0076035_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0147689_fig.json (deflated 82%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0230266_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0165279_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0269373_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0259769_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0201417_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0022380_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0207052_fig.json (deflated 38%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0202152_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0104213_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0005297_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0055216_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0013318_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0041057_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0118554_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0063487_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0049710_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0047075_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0188924_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0004378_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0119891_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0156550_fig.json (deflated 83%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0145709_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0153197_fig.json (deflated 80%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0175308_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0029323_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0032847_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1008859_fig.json (deflated 79%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0113949_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0192359_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0103416_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0201506_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0003093_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1008668_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0122163_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0198130_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0006560_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0079317_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1006451_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0167735_fig.json (deflated 52%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0138101_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0046421_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0055218_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0163494_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0090282_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0199431_fig.json (deflated 79%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0071406_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0162907_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0084198_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0203616_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0191086_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0180728_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0193561_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0182503_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0133501_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0242293_fig.json (deflated 52%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0162310_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0082414_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0226810_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0155986_fig.json (deflated 80%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0188058_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0211960_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0111500_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0031898_fig.json (deflated 54%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0070000_fig.json (deflated 80%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0181088_fig.json (deflated 83%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0107792_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0101046_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0191529_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0044657_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0176541_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0186394_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0133768_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0235697_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0148033_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0150498_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0040680_fig.json (deflated 52%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0125433_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0164505_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0161511_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0130626_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0148788_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0219071_fig.json (deflated 48%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0162314_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1000126_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0031581_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0162663_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0006408_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0113207_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0147909_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0021600_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0080469_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0166307_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0200830_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0005174_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0084299_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0169333_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0194877_fig.json (deflated 81%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0026227_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.3000357_fig.json (deflated 47%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.ppat.1003756_fig.json (stored 0%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0203866_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0259805_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0064467_fig.json (deflated 54%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1009914_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0210927_fig.json (deflated 53%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.1001420_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0084364_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0097029_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0106073_fig.json (stored 0%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0026207_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0032323_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0137723_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0149662_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0119166_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0208202_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0067973_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0257100_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0010213_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1006100_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0087306_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0098802_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1005361_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0017410_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0034877_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0018997_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0101458_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0170593_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1002820_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0004999_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0093786_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0035472_fig.json (deflated 79%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0170549_fig.json (deflated 37%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0182667_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0159195_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0213936_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0232936_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0082490_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0011968_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0001907_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0009396_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0143258_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0218168_fig.json (deflated 82%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0176384_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0140629_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1009939_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0148203_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0125059_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0229984_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0185683_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0075215_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0226203_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0142632_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0119935_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0004678_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0004190_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0101757_fig.json (deflated 53%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0112854_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0151387_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0145923_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0067818_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0208682_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0159997_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0125307_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0020324_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0021553_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0010485_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0257225_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0025891_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0041599_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0183769_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0005406_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0217084_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0057373_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0018790_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0018770_fig.json (deflated 54%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0185491_fig.json (deflated 51%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0180930_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0138031_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0194247_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0027791_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0257889_fig.json (deflated 54%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0121820_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0199327_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0236200_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0099223_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0076221_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1000550_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0179483_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0007873_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0016675_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0235819_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0002139_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0017825_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0058038_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0047646_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0007465_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0089769_fig.json (deflated 54%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0227797_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0029973_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0009978_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0027834_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0206195_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0064177_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0123052_fig.json (deflated 79%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0119330_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0117159_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.1000341_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0053704_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0209403_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0247400_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0006263_fig.json (deflated 51%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0008683_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0200027_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0123715_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0081581_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0092453_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0074148_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0057588_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0067889_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0044555_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0228310_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0071573_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0017906_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0115679_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0080641_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0057947_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0092619_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0101413_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0097722_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0141976_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0148107_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0158170_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0067367_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0155634_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0100611_fig.json (deflated 57%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0002535_fig.json (deflated 56%)
# ...
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0240770_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0197864_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0162114_fig.json (stored 0%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0198356_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0050152_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0152147_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0222069_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0160566_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0206145_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0098430_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0259651_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0102592_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0196669_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0122575_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0054119_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0090750_fig.json (stored 0%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0071248_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1002867_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0141355_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0160895_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0080658_fig.json (deflated 59%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0184632_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0200121_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0107395_fig.json (deflated 38%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0159450_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0019653_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0253631_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0069087_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0050784_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0041781_fig.json (deflated 52%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0191859_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0117669_fig.json (deflated 77%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0053646_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0058998_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0251061_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0197636_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0006825_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0180137_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0129027_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0157136_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0148363_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0227381_fig.json (deflated 52%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0231641_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0011455_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0197884_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0117920_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0051315_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0199295_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0157706_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0132713_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0195001_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0059829_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1006484_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0128042_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0059853_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0234208_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0170101_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0164253_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0029232_fig.json (deflated 38%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0125074_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0186140_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0174749_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0170276_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0217956_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0009617_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0138995_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0036432_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0190467_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0255978_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0157423_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0099277_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0118116_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pbio.1001637_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0011567_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.ppat.1003135_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0202870_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0169243_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0006907_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0193591_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0124020_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pgen.1004363_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0157120_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0169310_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0128363_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0008222_fig.json (deflated 54%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0008509_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0065427_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0091635_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0238557_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0232448_fig.json (deflated 58%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1000843_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0269308_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0176952_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0153964_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0226782_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0025172_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0181279_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0052596_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0243445_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0182283_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0195517_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0005160_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0134953_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0007298_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0038345_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0044075_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0074397_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0114674_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0065464_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0046049_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0151265_fig.json (deflated 41%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0153661_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0166420_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pcbi.1007015_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0070165_fig.json (deflated 69%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0205840_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0127727_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0009725_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0241366_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0198732_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0027534_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0078804_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0115774_fig.json (deflated 74%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0105818_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0007666_fig.json (deflated 41%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0111706_fig.json (deflated 53%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0255451_fig.json (deflated 81%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0205296_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0054159_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0072572_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0124660_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0083090_fig.json (deflated 78%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0024864_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0070501_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0240061_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0120924_fig.json (deflated 80%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0246860_fig.json (deflated 70%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0122264_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0080855_fig.json (deflated 75%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0248855_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0200956_fig.json (deflated 50%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0099871_fig.json (deflated 76%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0075821_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0250857_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0152070_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0256345_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0017050_fig.json (deflated 72%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0220892_fig.json (deflated 56%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0038293_fig.json (stored 0%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0165995_fig.json (deflated 79%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0116650_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0047674_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0171419_fig.json (deflated 89%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0149711_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0110127_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0113446_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0131498_fig.json (deflated 60%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0039683_fig.json (deflated 55%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0144674_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0042154_fig.json (deflated 39%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0073368_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0239489_fig.json (deflated 61%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pntd.0001652_fig.json (deflated 53%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0186809_fig.json (deflated 64%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0156285_fig.json (deflated 73%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0102887_fig.json (deflated 71%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0111189_fig.json (deflated 65%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0046105_fig.json (deflated 62%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0011651_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0073711_fig.json (deflated 46%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0212120_fig.json (deflated 67%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0045855_fig.json (deflated 66%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0151624_fig.json (deflated 68%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0111876_fig.json (deflated 63%)
#   adding: content/xml/parsed_plos_fig/10.1371-journal.pone.0109593_fig.json (deflated 68%)

# %%
# !zip -r /content/parsed_plos_para.zip /content/xml/parsed_plos_para
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0239847_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0114982_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0088945_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0025172_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0028920_paragraphs.json (deflated 50%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0126932_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0236556_paragraphs.json (deflated 72%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0194429_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0103389_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0108379_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0249547_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0246162_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0130278_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0268402_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0007277_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pgen.1002436_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0050955_paragraphs.json (deflated 71%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0193430_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0066713_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0062419_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0092476_paragraphs.json (deflated 55%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.2000724_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0226002_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1003529_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0158917_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0005108_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0209031_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0062431_paragraphs.json (deflated 73%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0113698_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0228742_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0183903_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0221951_paragraphs.json (deflated 72%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0162564_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0021062_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0112764_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0165662_paragraphs.json (stored 0%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0156434_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0074371_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0056492_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0167266_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0215037_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0079902_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0228588_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0033975_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0263122_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0044134_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0078379_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0262116_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0157423_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0131986_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0159997_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0244220_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0154144_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0238034_paragraphs.json (deflated 55%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0019762_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0149236_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0175662_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0054179_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0062671_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0023005_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0148822_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0192869_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0117467_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0129420_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0005484_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0226676_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0157890_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0082492_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.ppat.1009313_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0022307_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0265136_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0125239_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1003398_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0154231_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0181980_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0102430_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0025026_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0041526_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0237111_paragraphs.json (deflated 55%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0178389_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0221279_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0131072_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0205202_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0099151_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0034896_paragraphs.json (deflated 51%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0002802_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0108256_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0028660_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0074884_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0005377_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0185247_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0022729_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0117553_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0244932_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0026619_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0224308_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0062842_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0110856_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0160179_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0019265_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0028484_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0102920_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0031493_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0094524_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0124299_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0088488_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0186756_paragraphs.json (deflated 52%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0205203_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0168212_paragraphs.json (deflated 52%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0235475_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0238557_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0049623_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0149237_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0172977_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0106452_paragraphs.json (deflated 51%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0029080_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0165758_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0238595_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0099241_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0257226_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0143982_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0132967_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0248863_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0146958_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0095591_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0235890_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0160417_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0004620_paragraphs.json (deflated 44%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0016385_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0231727_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0018420_paragraphs.json (deflated 47%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0234166_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0185648_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0118180_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0070262_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.1000433_paragraphs.json (stored 0%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0202976_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.ppat.1007185_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0100577_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0210552_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0007921_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0244750_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0016743_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0057944_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0070728_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0125788_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0169515_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0008797_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0028922_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0087189_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0200654_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0062763_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0251421_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0125812_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0040205_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0184080_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pgen.1006464_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0074713_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0251256_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.3000094_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0238219_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1003706_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0003093_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0031707_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0196746_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0165388_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0081456_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0078219_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.3000158_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0110458_paragraphs.json (deflated 48%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0109736_paragraphs.json (deflated 39%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0184073_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0150932_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0011656_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0263462_paragraphs.json (deflated 73%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0166512_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0026412_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0194217_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.ppat.1007712_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0214573_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0049576_paragraphs.json (deflated 55%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.1002307_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0146441_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0015109_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0150468_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0189482_paragraphs.json (deflated 41%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0041764_paragraphs.json (deflated 72%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0038295_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0103076_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0007748_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0097279_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0244812_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0141435_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0237115_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0028584_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0001513_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0084098_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0094323_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0115414_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0016898_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0080968_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0184554_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0083221_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0013102_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0226857_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0240246_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0118669_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.ppat.1003053_paragraphs.json (stored 0%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0133992_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0121965_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0172107_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0159495_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0003028_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0130188_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0057770_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0019449_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0110854_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0007504_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0035224_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0219071_paragraphs.json (deflated 46%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0254416_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0045787_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0108651_paragraphs.json (deflated 52%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0129509_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0202212_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0023607_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0163121_paragraphs.json (deflated 74%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0093088_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0029834_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1005361_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0099571_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0042229_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1009643_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0000734_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0037223_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0216129_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0220320_paragraphs.json (stored 0%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pgen.1002489_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0014048_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0261682_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0029607_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0214658_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0134312_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0201257_paragraphs.json (deflated 50%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0190536_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0222273_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0151624_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0044847_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0106185_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0005736_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0019254_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0132054_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0174812_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0045106_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0167795_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0135786_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0070978_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pgen.1002820_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0112067_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0212128_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0148241_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0189205_paragraphs.json (deflated 72%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0255416_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0115539_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0171104_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0207052_paragraphs.json (deflated 37%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0075794_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0106649_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0001636_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0071255_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0169056_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0262416_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0103933_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0038621_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0183465_paragraphs.json (deflated 52%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0233627_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0046578_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0203657_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0011618_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0046873_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0118116_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.ppat.1003550_paragraphs.json (deflated 42%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0069511_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0220539_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0015822_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0128184_paragraphs.json (deflated 74%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0222327_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0176269_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.1001106_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0052114_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0061060_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0233071_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0000836_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0261344_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0258003_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0124656_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0199811_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0095703_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0049824_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0026658_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0258594_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0143241_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0159941_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0249377_paragraphs.json (deflated 48%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0031314_paragraphs.json (deflated 71%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0203540_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0187461_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0081787_paragraphs.json (deflated 71%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0044246_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0160438_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0145598_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0110929_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0011893_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0110500_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0166912_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0000824_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0181188_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0008940_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0208706_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0147044_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0039683_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0171082_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0056109_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0065735_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0187704_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0210766_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0199126_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0011430_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0010668_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0117138_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0224520_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0201665_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0203478_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0002026_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0020239_paragraphs.json (deflated 71%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0087892_paragraphs.json (deflated 71%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0186266_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0151232_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0136063_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0067720_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0001448_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0181914_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0226326_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0248788_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0046257_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0151941_paragraphs.json (deflated 48%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0074999_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0005377_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0144089_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0193085_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1005747_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0080858_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0086058_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0059784_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0139421_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0063708_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1007896_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0019051_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0028535_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0038656_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0050358_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0192346_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0028061_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0000444_paragraphs.json (deflated 44%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0061746_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0148034_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0223134_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0066893_paragraphs.json (stored 0%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0201117_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0104140_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0154631_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0228383_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1007537_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0168452_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0100173_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0205575_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0118455_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0235932_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0237261_paragraphs.json (stored 0%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0003009_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0143637_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0118245_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0057533_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0098694_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0229600_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0156057_paragraphs.json (deflated 73%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0022269_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0198109_paragraphs.json (deflated 55%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0006485_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0207887_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0082464_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0035272_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.0030282_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0040550_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0048859_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0194848_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.1002353_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0237882_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0201741_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0118896_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0129140_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0196839_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0101429_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0077093_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0227396_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0182502_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0053514_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0175138_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0047439_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0105495_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0005293_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0038857_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0009950_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0140486_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0049870_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0231553_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0112069_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0084568_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0050353_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0177145_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0016868_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0196440_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.1002015_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0060537_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0183999_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0151436_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0011835_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0242143_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0019514_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0115395_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0127679_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0138785_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0036230_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0045543_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0115884_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0078290_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0203072_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0064385_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0034528_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0179148_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0023938_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0091046_paragraphs.json (deflated 77%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0090173_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0014424_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0203737_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0260215_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0015160_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0052083_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0176498_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0130299_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0031374_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0032066_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0008959_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0200954_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0229047_paragraphs.json (deflated 74%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0204128_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0258791_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0081642_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0003578_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0170540_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0056131_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0021466_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0082831_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0080870_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0186259_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0158271_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0102232_paragraphs.json (deflated 50%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0059356_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0032980_paragraphs.json (deflated 52%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0165995_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0049665_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0036881_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0072296_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0103367_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0093184_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0062221_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0205624_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0058624_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0205116_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0025695_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0216270_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0186183_paragraphs.json (deflated 72%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.1001892_paragraphs.json (stored 0%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0219626_paragraphs.json (deflated 48%)
# ...
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.1000432_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0227239_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0259626_paragraphs.json (deflated 53%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0007137_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0005102_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0033995_paragraphs.json (deflated 55%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0039089_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0170683_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0143254_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0191396_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0170593_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0075962_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0049081_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0077686_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0059736_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0111706_paragraphs.json (deflated 55%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0042489_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0223241_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0154736_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1002029_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0107341_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pgen.1004075_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0166209_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0004396_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0028388_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.1001382_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0210952_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0075516_paragraphs.json (deflated 58%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0025144_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.ppat.0020095_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0180728_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0107669_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0004379_paragraphs.json (deflated 55%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0120248_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0090282_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0132346_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0131630_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0086604_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0062464_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0181649_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0164330_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0165743_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1002784_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0014280_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0216250_paragraphs.json (stored 0%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0227420_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0095207_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0122412_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0111086_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0124842_paragraphs.json (deflated 47%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0056789_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0222561_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0053066_paragraphs.json (deflated 49%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0226471_paragraphs.json (deflated 74%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0107198_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0167829_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0025757_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0173130_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0010034_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0171678_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0063601_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0212688_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0047882_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0041058_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0246390_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0072506_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0077598_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0094341_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0154647_paragraphs.json (stored 0%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0074505_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0178240_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0146274_paragraphs.json (deflated 71%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0092043_paragraphs.json (deflated 51%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0164108_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0256427_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0250403_paragraphs.json (deflated 77%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0067568_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pgen.1006489_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0244210_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0025609_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0134355_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0062394_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0087426_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0228067_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0102661_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0016111_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0141167_paragraphs.json (deflated 49%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0157174_paragraphs.json (deflated 70%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0025776_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1004095_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0214986_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0104882_paragraphs.json (deflated 49%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0107018_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0199333_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0020168_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0148280_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0140423_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0237527_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pstr.0000010_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0065226_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0081327_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0004823_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0008250_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0228367_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0107688_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0005288_paragraphs.json (deflated 32%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0133383_paragraphs.json (deflated 55%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0174634_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0226474_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0221800_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0032940_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0111889_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0039054_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0183143_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0061827_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0205407_paragraphs.json (deflated 59%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0136373_paragraphs.json (deflated 31%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0111519_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0124057_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0152335_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0103645_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0239690_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0040857_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0134521_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0184311_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0002393_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pbio.2004261_paragraphs.json (stored 0%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0243760_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0077736_paragraphs.json (deflated 63%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0062176_paragraphs.json (deflated 69%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0038730_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0241093_paragraphs.json (deflated 66%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.ppat.1002796_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0052719_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0177778_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0106650_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0116719_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0145449_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0056678_paragraphs.json (deflated 57%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0205296_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0001609_paragraphs.json (deflated 61%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0233669_paragraphs.json (deflated 56%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0141488_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pcbi.1008643_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0133376_paragraphs.json (deflated 62%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0091125_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0035223_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0160012_paragraphs.json (deflated 55%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0145933_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0263998_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pntd.0003163_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0206778_paragraphs.json (deflated 67%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0106752_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0089807_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0234431_paragraphs.json (deflated 54%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0231801_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0225438_paragraphs.json (deflated 68%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0112657_paragraphs.json (deflated 60%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0189626_paragraphs.json (deflated 64%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0205900_paragraphs.json (deflated 65%)
#   adding: content/xml/parsed_plos_para/10.1371-journal.pone.0153972_paragraphs.json (deflated 64%)

# %%
plos = Biorxiv_Plos_Parser('/content/xml/xml/10.1371-journal.pntd.0010019.xml', 'plos')

# %%
os.mkdir('xml/not_working')
json.dump('/content/xml/xml/10.1371-journal.pntd.0010019.xml', open('xml/not_working/10.1371-journal.pntd.0010019.xml', 'w'))

# %%
path = '/content/xml/xml/10.1371-journal.pntd.0010019.xml'
tree = ET.parse(path)
with open('/content/xml/not_working/10.1371-journal.pntd.0010019.xml', 'wb') as f:
    tree.write(f)
